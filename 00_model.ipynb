# %%
import flopy
import pyemu
import shutil
import numpy as np
import pandas as pd
import geopandas as gpd
import ipywidgets as widgets
import matplotlib.pyplot as plt
from pathlib import Path
from mf6rtm import utils, mup3d
from flopy.utils import  cvfdutil
from vorflow import ConceptualMesh, MeshGenerator, VoronoiTessellator
from vorflow.utils import *
from shapely import box, Point, LineString
from herebedragons import *
from IPython.display import display

# %% [markdown]
# # Background and conceptualization

# %% [markdown]
# If you want the tl;dr version, go to the next cells
#
# This tutorial is based on the DIZON (Deep well injection in Zuid-Oost Nederland) site study: a field Aquifer Storage and Recovery (ASR) experiment and accompanying reactive transport model originally published in [Prommer and Stuyfzand, 2005](https://pubs.acs.org/doi/10.1021/es0486768). Here we present a version updated to `mf6rtm` and slightly modified to convert into an decision-support case/tutorial.
#
#
# ## Summary
#
# This model couples three-dimensional groundwater flow, heat transport, and multicomponent geochemistry to simulate a deep well injection experiment in a pyrite-rich aquifer. Oxic surface water with seasonally varying temperature is injected into an anoxic system, triggering pyrite oxidation that consumes oxygen and nitrate and produces sulfate and acidity. Reaction rates are explicitly temperature-dependent, which proves essential for reproducing observed seasonal patterns in redox chemistry. The model shows that pyrite oxidation dominates redox processes, while organic matter plays a minor role, and highlights the importance of integrating temperature, transport, and geochemistry when interpreting field-scale recharge experiments.
#
# ## Key points
#
# ### Conceptual Model
#
# - **System setup**
#   - Injection of **oxic, pretreated surface water** into a **deep, anoxic aquifer**
#   - Aquifer contains **pyrite (FeS₂)** and minor sediment-bound organic matter
#   - Injection and recovery wells create a **three-dimensional flow field**
#
# - **Primary geochemical control**
#   - **Pyrite oxidation** is the dominant reaction controlling water quality
#   - Pyrite reacts with:
#     - Dissolved oxygen
#     - Nitrate
#   - Reaction products include:
#     - Sulfate
#     - Acidity (H⁺)
#     - Ferric iron precipitates (Fe(OH)₃)
#
# - **Role of temperature**
#   - Injected water temperature varies **seasonally**
#   - Reaction rates increase strongly with increasing temperature
#   - Temperature controls:
#     - Where oxidants are consumed
#     - How fast redox fronts migrate
#
# ### Model Structure
#
# - **Flow and solute transport**
#   - Fully **3D groundwater flow and transport**
#
# - **Heat transport**
#   - Temperature modeled as a **retarded tracer**
#   - Seasonal thermal signals propagate more slowly than solutes
#   - Simulated temperature fields directly control reaction rates
#
# - **Reactive transport**
#   - Multicomponent reactive transport framework
#   - Includes:
#     - Equilibrium aqueous speciation
#     - Redox reactions
#     - Cation exchange
#     - Mineral equilibrium (Organic matter)
#   - Kinetically controlled reactions:
#     - Pyrite oxidation that is temperature-dependent
#
# ### Key aspects to consider
#
# - **Dominant reaction pathway**
#   - Pyrite oxidation consumes most of the injected oxidizing capacity
#
# - **Seasonal redox behavior**
#   - Cold injection water:
#     - Slower reaction rates
#     - Oxygen and nitrate penetrate farther into the aquifer
#   - Warm injection water:
#     - Faster reaction rates
#     - Rapid oxidant removal close to the injection well
#
# - **Importance of temperature**
#   - Models without temperature-dependent kinetics fail to reproduce:
#     - Oxygen breakthrough
#     - Nitrate removal patterns
#   - Including temperature dependence reproduces observed seasonal dynamics
#
# - **Effect of aquifer heterogeneity**
#   - Variations in hydraulic conductivity and pyrite content cause:
#     - Depth-dependent redox zonation
#     - Location-specific reaction rates
#
# - **Reactive vs nonreactive comparison**
#   - Nonreactive simulations isolate physical transport effects
#   - Reactive simulations quantify:
#     - Sulfate production from pyrite oxidation
#     - True extent of oxygen and nitrate consumption
#
# - **Extraction well water quality**
#   - Seasonal chemical signals are damped by mixing and dispersion
#   - Long-term trends reflect cumulative pyrite oxidation

# %% [markdown]
# # Decision-support objective
#
# We are injecting oxic and hotter water (pre-treated) into an anoxic and slighlty cooler aquifer with a lot of pyrite.
# This will release a lot sulfate from pyrite oxidation.
#
# We want to extract water from a well for drinking supply and we want to minimize the concentration of sulfate of the extracted water so we have lower water treatment costs.
#
# Easy right?

# %% [markdown]
# # Basemodel creation
#
# A few considerations for the model before we begin:
#
# - We are using a disv - voronoi grid with refinements on each extraction well.
# - Temperature is going to be modelled as a species with sorption (retardation) to simulate heat exchange with the aquifer.
# - 35 stress periods with daily time steps.
# - Three pumping wells:
#     - wellin : injection well on the whole simulation
#     - wellout: extraction well on from stress period 0 to 20.
#     - wellopt: extraction well on from stress period 21 to the end and is the one we want to use the water
# - Regional aquifer: CHDs left and right

# %% [markdown]
# ## Grid and domain

# %%
domain = gpd.read_file(Path('data', 'domain.gpkg'))
Ly = domain.geometry.total_bounds[3] - domain.geometry.total_bounds[1]
Lx = domain.geometry.total_bounds[2] - domain.geometry.total_bounds[0]

xul = domain.geometry.total_bounds[0]
yul = domain.geometry.total_bounds[1]

domain_ext = box(xul, yul, xul + Lx, yul +  Ly)
domain_ext

# %%
wells = pd.read_csv(Path('data', 'wells.csv'))
refinement = gpd.read_file(Path('data', 'refinement.gpkg'))

# %%
geom = refinement.geometry[0]
minx, miny, maxx, maxy = geom.bounds

# Create line from bottom-left to bottom-right of top edge
top_line = LineString([(minx, maxy), (maxx, maxy)])
bottom_line = LineString([(minx, miny), (maxx, miny)])

# %%
background_lc = 150.0

blueprint = ConceptualMesh()
blueprint.add_polygon(domain_ext, zone_id=1)#,border_density=100,dist_max_in=background_lc)

blueprint.add_line(bottom_line, line_id="Refinement-Line",
                     resolution=20,
                        dist_max=1*background_lc,
                        # z_order=3
                        )

for wid in wells.index:
    blueprint.add_point(Point(wells.loc[wid, 'x'], wells.loc[wid, 'y']), point_id=f"{wells.loc[wid, 'name']}", 
                    resolution=3,
                    dist_max=1.5*background_lc)
    print(f"Added well {wells.loc[wid, 'name']} at ({wells.loc[wid, 'x']}, {wells.loc[wid, 'y']})")
clean_polys, clean_lines, clean_pts = blueprint.generate()

# 2. Mesh Generation
mesher = MeshGenerator(background_lc=background_lc, verbosity=0)
mesher.generate(clean_polys, clean_lines, clean_pts)

# 3. Voronoi Conversion
tessellator = VoronoiTessellator(mesher, blueprint, clip_to_boundary=True)
grid_gdf = tessellator.generate()

# %% [markdown]
# Let's have a look at the domain, grid and the pumping wells

# %%
fig, ax = plt.subplots(1, 1)

grid_gdf.plot(
    ax=ax,
    alpha=0.5,
    edgecolor='k',
    linewidth=0.2
)
domain.dissolve().boundary.plot(
    ax=ax,
    alpha=1,
    edgecolor='r',
    linewidth=1
)

cmap = plt.cm.tab10  # good for categorical data
colors = cmap(np.linspace(0, 1, len(wells)))

for (i, row), color in zip(wells.iterrows(), colors):
    ax.scatter(
        row['x'],
        row['y'],
        facecolor=color,
        edgecolors='black',
        marker='o',
        s=50,
        label=row['name'],
        zorder=10
    )

ax.legend()

ax.set_aspect('equal')
fig.tight_layout()

# %%
gdf = calculate_mesh_quality(grid_gdf,calc_ortho=True)
# gdf.plot(column='drift_ratio', cmap='viridis', legend=True, figsize=(10,8),vmax=.25, aspect='equal')
summarize_quality(gdf)

grid_gdf.to_file(Path("data", "mf6_grid.shp"))

# %% [markdown]
# Let's define some functions

# %%
def make_gwf(ws, tracer = 'Cl', mup3d_m = None):

    flow_modelname = "gwf"
    perioddata= [(2, 2, 1), (4, 4, 1), (4, 4, 1), (4, 4, 1), (7, 7, 1),
                (7, 7, 1), (7, 7, 1), (7, 7, 1), (14, 14, 1), (14, 14, 1), 
                (15, 15, 1), (13, 13, 1), (14, 14, 1), (14, 14, 1), (14, 14, 1), 
                (21, 21, 1), (35, 35, 1), (28, 28, 1), (28, 28, 1), (28, 28, 1), 
                (28, 28, 1), (28, 28, 1), (28, 28, 1), (28, 28, 1), (28, 28, 1),
                (35, 35, 1), (35, 35, 1), (28, 28, 1), (28, 28, 1), (28, 28, 1), 
                (35, 35, 1), (35, 35, 1), (28, 28, 1), (28, 28, 1), (28, 28, 1), 
                # (28, 28, 1), (35, 35, 1), (35, 35, 1), (28, 28, 1),
                ]
    nper = len(perioddata)  # Number of stress periods
    sim = flopy.mf6.MFSimulation(sim_name=f"{flow_modelname}", version='mf6', sim_ws=ws)
    utils.prep_bins(ws, get_only=['mf6', 'libmf6', 'pestpp-ies', 'pestpp-mou'])
    # ?utils.prep_bins

    # specify tdis
    tdis = flopy.mf6.ModflowTdis(sim, pname="tdis", time_units="DAYS", 
                                    nper=nper, perioddata=perioddata)
    outer_dvclose = 1e-3
    inner_dvclose = 1e-3
    ims = flopy.mf6.ModflowIms(sim, 
                            #    pname="ims", 
                            complexity="complex",
                            outer_dvclose=outer_dvclose,
                            inner_dvclose=inner_dvclose,
                            filename=f"{flow_modelname}.ims")
    sim.register_ims_package(ims, 
                                [flow_modelname])

    # start model build to refine 
    model_nam_file = "{}.nam".format(flow_modelname)
    gwf = flopy.mf6.ModflowGwf(sim, modelname=flow_modelname, 
                                model_nam_file=model_nam_file, exe_name='mf6')

    # read verts and iverts from shapefile
    verts, iverts = cvfdutil.shapefile_to_cvfd('data/mf6_grid.shp')

    # get ncpl, nvert, vertices and cell2d from verts, iverts
    gridprops = cvfdutil.get_disv_gridprops(verts, iverts, xcyc=None)

    disv = flopy.mf6.ModflowGwfdisv(gwf,
                                    nlay=12, # 12-layer model
                                    ncpl=gridprops['ncpl'],
                                    nvert=gridprops['nvert'],
                                    vertices=gridprops['vertices'],
                                    cell2d=gridprops['cell2d'],
                                    top=-273.0,
                                    botm=0.0,
                                    filename=f"{flow_modelname}.disv")

    # get the bottoms/tops from the original model
    botms = get_botms(gwf, ws)

    disv.botm.set_data(botms)
    disv.set_all_data_external()

    nlay = disv.nlay.get_data()
    ncpl = disv.ncpl.get_data()

    ihead = 0 #(meters)
    strt = ihead * np.ones((nlay, ncpl))
    ic = flopy.mf6.ModflowGwfic(gwf, pname="ic", strt=strt)
    ic.set_all_data_external()

    npf = flopy.mf6.ModflowGwfnpf(
            gwf,
            icelltype=0,
            k=np.ones((nlay, ncpl)),
            k33=np.ones((nlay, ncpl)),
            # k33overk = True
        )
    npf.set_all_data_external()

    ss = np.ones((nlay, ncpl)) * 1.e-4
    sto = flopy.mf6.ModflowGwfsto(gwf, 
                                    ss=ss, 
                                    iconvert=0,
                                    # steady_state={0: False},
                                    transient={0: True})
    sto.set_all_data_external()

    chd = make_chd(gwf, conservative_tracer=tracer, mup3d_m=mup3d_m)
    # chd.export(Path(ws, f"chd.vtk"), fmt="vtk")

    welout = make_wel_out(sim, conservative_tracer=tracer, mup3d_m=mup3d_m)
    welin = make_wel_in(sim, conservative_tracer=tracer, mup3d_m=mup3d_m)
    welopt = make_wel_opt(sim, conservative_tracer=tracer, mup3d_m=mup3d_m)
    # disv.export(Path(ws, f"disv.vtk"), fmt="vtk")

    # create the output control
    headfile = f"{flow_modelname}.hds"
    head_filerecord = [headfile]
    budgetfile = f"{flow_modelname}.cbb"
    budget_filerecord = [budgetfile]
    saverecord = [("HEAD", "ALL"), ("BUDGET", "ALL")]
    printrecord = [("HEAD", "LAST")]

    oc = flopy.mf6.ModflowGwfoc(
        gwf,
        saverecord=saverecord,
        head_filerecord=head_filerecord,
        budget_filerecord=budget_filerecord,
        printrecord=printrecord)

    return gwf, sim

# %%
def make_gwt(sim, tracer = 'Cl', mup3d_m=None):

    # Base model parameters
    ne = 0.35 # effective porosity (-) constant across all layers
    long_disp = 0.1 # Longitudinal dispersivity (m)constant across all layers
    disp_tr_vert = long_disp*0.01 # Transverse vertical dispersivity (m) constant across all layers
    disp_tr_hor = long_disp*0.1 # Transverse horizontal dispersivity (m) constant across all layers
    diffc = 0 # diffusion coefficient constant across all layers
    pbulk = 1850 # bulk density in constant across all layers (m/L^3)

    gwf = sim.get_model('gwf')

    if mup3d_m is not None and tracer is None:
        components = mup3d_m.components
    else:
        components = [tracer]

    for comp in components:
        print(f"Setting transport for {comp}")
        model_name = comp
        gwt = flopy.mf6.MFModel(
            sim,
            model_type="gwt6",
            modelname=model_name,
            model_nam_file=f"{model_name}.nam"
        )
        outer_dvclose = 1e-3
        inner_dvclose = 1e-3
        ims = flopy.mf6.ModflowIms(sim, 
                                complexity="complex",
                                outer_dvclose=outer_dvclose,
                                inner_dvclose=inner_dvclose,
                                filename=f"{model_name}.ims")
        sim.register_ims_package(ims, 
                                [model_name])

        # Let's get dis/disv from parent gwf model
        dis = gwf.dis
        nlay = dis.nlay.get_data()
        ncpl = dis.ncpl.get_data()
        disv = flopy.mf6.ModflowGwfdisv(gwt,
                                        nlay=nlay,
                                        ncpl=dis.ncpl.get_data(),
                                        nvert=dis.nvert.get_data(),
                                        vertices=dis.vertices.get_data(),
                                        cell2d=dis.cell2d.get_data(),
                                        top=dis.top.get_data(),
                                        botm=dis.botm.get_data(),
                                        filename=f"{model_name}.disv")

        disv.set_all_data_external()

        if tracer is not None:
            strt = 2.540000e-04 # initial concentration for tracer
        else:
            strt = mup3d_m.sconc[comp] # initial concentrations handled by PHREEQC

        ic = flopy.mf6.ModflowGwtic(gwt, strt=strt, 
                                    filename=f"{model_name}.ic")
        ic.set_all_data_external()

        adv = flopy.mf6.ModflowGwtadv(
            gwt,
            scheme="tvd",
        )
        adv.set_all_data_external()

        alpha_l = np.ones(shape=(nlay,ncpl))*long_disp  # Longitudinal dispersivity ($m$)
        alpha_th = np.ones(shape=(nlay,ncpl))*disp_tr_hor  # Transverse horizontal dispersivity ($m$)
        alpha_tv = np.ones(shape=(nlay,ncpl))*disp_tr_vert  # Transverse vertical dispersivity ($m$)

        dsp = flopy.mf6.ModflowGwtdsp(
            gwt,
            xt3d_off=True,
            alh=alpha_l,
            ath1=alpha_th,
            atv = alpha_tv,
            diffc = diffc,
            filename=f"{model_name}.dsp",
        )
        dsp.set_all_data_external()

        sourcerecarray = [
                        ["welin", "aux", model_name],
                        ["welout", "aux", model_name],
                        ["welopt", "aux", model_name],
                        ["chd", "aux", model_name]
                        ]

        ssm = flopy.mf6.ModflowGwtssm(
                gwt,
                sources=sourcerecarray,
                save_flows=True,
                print_flows=True,
                filename=f"{model_name}.ssm",
            )
        ssm.set_all_data_external()

        if comp=='Tmp':
            # kd = 2*ne/1850
            distcoef = np.ones(shape=(nlay,ncpl))*2.1141E-04
            sorption = "Linear"
            pbulk = 1850
            bulk_density = np.ones(shape=(nlay,ncpl))*pbulk
            ne=0.35
        else:
            distcoef = None
            sorption = None
            bulk_density = None
            ne=0.35
        porosity  = np.ones(shape=(nlay,ncpl))*ne
        
        mst = flopy.mf6.ModflowGwtmst(
            gwt,
            porosity=porosity,
            first_order_decay=None,
            decay = None,
            decay_sorbed=None,
            sorption= sorption,
            bulk_density=bulk_density, 
            distcoef=distcoef, #Kd m3/mg
            sp2 = None,
            filename=f"{model_name}.mst",
        )
        mst.set_all_data_external()
        oc = flopy.mf6.ModflowGwtoc(
            gwt,
            budget_filerecord=f"{model_name}.cbb",
            concentration_filerecord=f"{model_name}.ucn",
            concentrationprintrecord=[("COLUMNS", 10, "WIDTH", 15, "DIGITS", 10, "GENERAL")
                                        ],
            saverecord=[("CONCENTRATION", "ALL"), 
                        ],
            printrecord=[("CONCENTRATION", "LAST"), 
                            ],
        )
        flopy.mf6.ModflowGwfgwt(
            sim,
            exgtype="GWF6-GWT6",
            exgmnamea='gwf',
            exgmnameb=f'{model_name}',
            filename=f"{model_name}.gwfgwt",
        )
        make_obs_pack(gwt)

    sim.write_simulation() 
    return sim

# %% [markdown]
# ## Conservative Transport Model
#
# Before adding complexity (chemistry booo) .. Let's dive into a bit of conservative transport for simplicity
#
# The functions defined above let us define transport `mf6` models from a `PHREEQC` object or using `FloPy` methods (as you would do for a conservative transport)
#
# The following cell those the latter. It creates a `mf6` simulation with only one transport model called Cl (for Chloride). We encourage to run it and inspect if you are not familiar with transport simulations.

# %%
ws = Path("model")

if ws.exists():
    shutil.rmtree(ws)

gwf, sim = make_gwf(ws, tracer = 'Cl', mup3d_m = None)
sim = make_gwt(sim, tracer = 'Cl', mup3d_m=None)

pyemu.os_utils.run(f"mf6", cwd=ws)

# %% [markdown]
# ## Chemistry and Reactive Transport Model
#
# This is the fun part (for some at least). Here is where we define our chemistry stuff a.k.a. reaction network for the reactive transport nerds!
#
# We have a few files in `data` that we will inspect and use to define the initial conditions and parameters for our reaction network. Let's inspect those and see what they contain!
#
# All of the chemistry setup has been included in a tidy function called `initialize_chemistry`.
# This function uses information from the `mf6` simulation defined above and also the class `mup3d` from `mf6rtm`.
# This class will help us to store chemistry inputs and will write the necessary files for us to run `mf6rtm` .. Think like FloPy

# %%
def initialize_chemistry(ws, sim, nlay, ncpl):
    perioddata = sim.tdis.perioddata.get_data()
    nper_model = sim.tdis.nper.get_data()

    # get the initial solution chemistry for the whole domain. In this case we are using an isotropic solution chemistry as base
    solutionsdf = pd.read_csv(Path("data","ic_aq_chem.csv"), index_col = 0)

    ## let's process the injection chemistry the following lines process the data in `wellin.csv` to get a nice array with the injection concentrations for each time step
    injdf = pd.read_csv(Path("data","wellin.csv"), index_col = 0)
    mask = injdf.index>int(nper_model/2)
    # injdf.loc[mask, 'O(0)'] *= 10 # let's add more Oxygen to make interesting
    # injdf.loc[mask, 'pH'] -= 4
    # injdf.loc[mask, 'Tmp'] *= 3
    injdf = injdf[['layer'] + solutionsdf.index.tolist()].copy()

    frames = []                     

    for per in injdf.index.unique():
        df = (
            injdf.loc[per].reset_index()      
                .drop(columns='kper')        
                .groupby('layer').mean()    
                .T                          
        )
        # give columns names like  0_1, 0_2, …   (or f"{per}_{layer}")
        df.columns = [f"{per}_{layer}" for layer in df.columns]

        frames.append(df)            

    # We have the injections and background concentrations in a dataframe
    # Let's concatenate them for easier processing 
    injdf = pd.concat(frames, axis=1) 
    solutionsdf = pd.concat([solutionsdf, injdf], axis=1)

    # mup3d works with dictionaries where each solution is associated to a numbered key (1-n solutions), so we need to transform that dataframe into one.
    # luckily for us we have utils to do that
    solutions = utils.solution_df_to_dict(solutionsdf)

    # the chemistry part of `mf6rtm` (i.e., phreeqcrm) requires us to define an array of the same shape as the grid
    # this array contains numbers 1-n where they denote the solution we want to define on each cell of the grid
    # in this case we are initiatiing and array of only ones (1s)
    # mup3d will do a match between this numbers and the defined keys of solutions
    sol_ic = np.ones((nlay, ncpl), dtype=float)

    solution = mup3d.Solutions(solutions)
    solution.set_ic(sol_ic)

    excdf = pd.read_csv(Path("data","ic_exchanger.csv"), comment = '#')
    ex_names = {
                "Ca_ex": "CaX2",
                "Fe_ex":"FeX2" ,
                "K_ex":"KX" ,
                "Mg_ex":"MgX2", 
                "Na_ex":"NaX"
                }
    # we need to rename to match the database
    excdf['name'] = excdf['var'].map(ex_names)
    excdf['layer'] -= 1  # convert to zero‑indexed
    excdf = excdf.pivot(index="name", columns="layer", values="value")
    exchanger_dict = excdf.to_dict()
    for k, subdict in exchanger_dict.items():
        for key in subdict:
            subdict[key] = {'m0': subdict[key]}

    exchanger = mup3d.ExchangePhases(exchanger_dict)

    layer_vals = np.arange(1, nlay + 1, dtype=float)   # shape (nlay,)

    # Broadcast to full 3‑D grid
    exchanger_ic = np.ones((1, ncpl))
    exchanger.set_ic(sol_ic)

    # we need to equilibrate the exchangers with the background solution
    # init background solution is the same (number 1) for the whole domain
    # the next array has a length of nlay, one for each layer
    eq_solutions = [1] * nlay
    exchanger.set_equilibrate_solutions(eq_solutions)

    mindf = pd.read_csv(Path("data","ic_surfaces.csv"), comment = '#')
    mindf['value'] = [utils.concentration_volbulk_to_volwater(i,0.35) for i in mindf['value'].values]
    mindf = mindf.pivot(index="var", columns="layer", values="value")

    # only ferrihydrite and orgmatter are in eq
    eq_m0 = utils.solution_df_to_dict(mindf.loc[['Ferrihydrite', "Orgmatter"],:])

    # we need the initial Sat indeces SI
    # following original model init SI is 0
    si = 0

    eq_dic = {}
    #lets add pyrite first
    for ly in range(nlay):
        for key in eq_m0.keys():
            # create a dictionary for each layer with key as the mineral name
            # and values as a dictionary with si and m0
        # si followed by m0 (init moles)
            eq_dic[ly] = {key: {}}
            eq_dic[ly][key]['si'] = si
            eq_dic[ly][key]['m0'] = eq_m0[key][ly]
            # eq_dic[ly+1] = {key: [si, eq_m0[key][ly]] for key in eq_m0.keys()}
    equilibriums = mup3d.EquilibriumPhases(eq_dic)
    equilibriums.set_ic(sol_ic)

    # Pyrite is kinetic
    py_m0 = utils.solution_df_to_dict(mindf.loc[["Pyrite"],:])

    # we need the kinetic params for Py
    kin_py_params = [1.600000e+01, 
                        6.700000e-01, 
                        5.000000e-01, 
                        -1.100000e-01]
    kin_dic = {}

    # lets add kinetics for Organic carbon (Orgc)
    kin_orgc_params = [1.570000e-09, 1.670000e-11, 1.000000e-13]
    # orgc also have a custom formula
    orgc_form =  "Orgc -1.0 CH2O 1.0"
    orgc_steps = "8.640000e+04 in 1 steps"

    #lets add pyrite first
    for ly in range(nlay):
        # print(ly+1)
        for key in py_m0.keys():
            kin_dic[ly] = {key: {}}
            kin_dic[ly][key]['m0'] = py_m0[key][ly]
            kin_dic[ly][key]['parms'] = kin_py_params
            # kin_dic[ly+1] = {key: [py_m0[key][ly], kin_py_params]}

    # lets add orgc now with a m0 of zero for all layers
    for key in kin_dic.keys():
        kin_dic[key]['Orgc'] = {}
        kin_dic[key]['Orgc']['m0'] = 1.0
        kin_dic[key]['Orgc']['parms'] = kin_orgc_params
        kin_dic[key]['Orgc']['formula'] = orgc_form
        kin_dic[key]['Orgc']['steps'] = orgc_steps

    kinetics = mup3d.KineticPhases(kin_dic)
    kinetics.set_ic(sol_ic)
    model = mup3d.Mup3d('model',solution, nlay=nlay, ncpl=ncpl)

    # #set model workspace
    model.set_wd(ws)

    # set database
    # shutil copy datab
    shutil.copy(Path("data", f'datab.dat'), Path(model.wd, f'datab.dat'))
    database = Path(f'datab.dat')
    model.set_database(database)

    postfix = Path("data", f'postfix.phqr')
    model.set_postfix(postfix)
    model.set_exchange_phases(exchanger)
    model.set_phases(kinetics)
    model.set_phases(equilibriums)

    # mf6rtm let us run reactions whenever we want. Isn't it a good fella?!
    # To do this we only need to pass a list of tuples to mf6rtm with like
    # [(kper, kstep)] and pass "timing":'user' below
    tsteps = create_reactive_tsteps(perioddata, output_interval=7)

    model.set_config(
                    reactive={
                    "timing":'user', # this can be user or all, we use 'user'
                    "externalio":True, # flag to write external files
                    "tsteps":tsteps, # the pairs kper, kstp we want to run reactions on
                    }
                    )
    model.set_componenth2o(True)
    model.initialize(add_charge_flag=False)
    return model

# %% [markdown]
# Take a moment to go through the function above ... if you have any questions, please post an issue on this repo
#
# The following lines of code are pretty straight forward, We already have a conservative transport simulation/model in the folder `model`. We are going to read that simulation with FloPy
# and getting the number of layers and nodes per layer (ncpl). Finally, we initilize the chemistry by running the function defined above.
#
# Take a look at what is printed.
#
# mf6rtm is warning us that we are writing external files for exchange, equilibrium and kinetic phases.
# In addtion, it printed the stress periods and time steps when reactions will be invoked.

# %%
ws = Path("model")

sim = flopy.mf6.MFSimulation.load(sim_ws = ws,
                                sim_name = 'gwf', 
                                version='mf6',
                                    exe_name='mf6',
                                    verbosity_level=0)
gwf = sim.get_model("gwf")
nlay = gwf.dis.nlay.get_data()
ncpl = gwf.dis.ncpl.get_data()

# let's clean the folder just in case
if ws.exists():
    shutil.rmtree(ws)

mup3d_m=initialize_chemistry(ws, sim, nlay, ncpl)

# %% [markdown]
# Up to here, only the chemistry files are written.
#
# Next, we re-write the `mf6` files, but for a multi-species simulation.

# %%
gwf, sim = make_gwf(ws,tracer=None, mup3d_m=mup3d_m)
sim = make_gwt(sim, tracer=None, mup3d_m=mup3d_m)

# %% [markdown]
# Done!, we are ready to roll ... Let's run the basemodel. This takes a while (~6 min in MacOS or Linux and ~10-15 min in Windows). Reactive transport models tend to be slow.

# %%
pyemu.os_utils.run(f"mf6rtm", cwd=ws)

# %% [markdown]
# # Measured data
#
# Before jumping into the *PESTverse*, let’s take a quick look at the measured data and monitoring wells. All observations used here live in:
#
# `./data/obs_chem_cleaned.csv`
#
# In a rare win for a tutorial, we actually have **real measured data**. The dataset includes measurements from **four monitoring sites** and for the **injection/extraction wells** covering the full simulation period. Each site may have data from **multiple screened intervals** at different depths.
#
# That said, most of this tutorial works with a **synthetic truth**. We pick one realization from the ensemble, declare it to be the “real” system, and remove it from the ensemble. The remaining realizations are then used for history matching, posterior analysis (DSI), and optimization — all of which are introduced in the next notebooks.
#
# So, why putting the real data then!
#
# Well ...
#
# If you’re feeling adventurous, you’re absolutely encouraged to try history matching using the **real data** instead. To make this easier, we’ve included an **IES notebook** that does exactly that.
#
# One last thing: when you open the CSV, you’ll notice some monitoring sites with no data (empty rows). These are just **placeholders** that define observation locations we’ll track with PESTPP later on. Don’t worry — this will make sense soon enough.
#
# Let's have a look at what we wanna "observe" during this tutorial

# %% [markdown]
# Loading and printing the first rows of the measured data we can see a few things already. Data is in mol per liter or Molar (chemistry wink). We are lucky that the default output from `mf6rtm` is Molar too.
#
# **obsid** denotes the name of our measured sites. **variable** is the chemical concentration or property that we are tracking for each measured **time**. Finally, **x**, **y** and **layer** tell us the location of each site.

# %%
meas_data = pd.read_csv(Path("data", "obs_chem_cleaned.csv"))
meas_data.head()

# %% [markdown]
# Let's have a look at the sites and chemical variables we have available

# %%
display(meas_data.obsid.unique())

display(meas_data.variable.unique())

# %% [markdown]
# We have **lots of monitoring sites** and, even more surprisingly, **lots of chemical quantities** that we could track. If you’re coming from a flow-modelling background, this can feel pretty damn scary — you’re probably used to dealing with heads and flows, and not much else.
#
# To keep things simple in this tutorial, we’re going to focus on **just two chemical quantities** across **three monitoring sites**. For now, we’ll pretend the rest of the data doesn’t exist. That said, nothing is stopping you from choosing your own adventure later on and bringing more sites or species into the mix once you’re comfortable.
#
# The sites we are going to focus are:
#
# - wp1-f3
# - wp4-f5
# - welopt-ly3
#
# Similarly we are going to focus in a couple of species/properties:
# - sulfate (we want to minimize that)
# - pH
# - temp
#
# Let's move to some initial plots to check the model

# %% [markdown]
# # Let's inspect the basemodel outputs
#
# That's it! We have our basemodel up and running. The next step is something a lot people enjoy: inspecting, playing the basemodel and checking that everything is set up correctly. It's also a good opportunity to check the base model against your conceptualization.
#
# Next up! We have our simulation outputs and measured chemical data ready. The next step is something that most modelling project will go before moving into the PESTverse: lining up simulated and observed outputs and seeing how they fit. It's a great way to check that the model is behaving as expected at your observation points, verify that your grid and layers are correctly representing your system, and get a sense of where the model captures the observation data and where it might need a little tweak. The function (`process_sim_conc`) processes the data so that for each observation location, layer, and chemical variable, you get simulated and measured values side-by-side at each time step — perfect for plotting and history-matching.

# %%
# let's bring a copy of the measured data into the working directory
shutil.copy(Path("data", "obs_chem_cleaned.csv"), Path("model", "obs_chem_cleaned.csv"))

fname, obs = process_sim_conc(wd='model')

# %%
obs = pd.read_csv(Path('model', fname))
cols = ["sim", "meas"]
obs[cols] = obs[cols].mask(obs[cols] >= 1e30, np.nan)

obs_to_plot = ['welopt-ly1', 'wp1-f3', 'wp4-f5']

variables = sorted(obs["variable"].unique())
# variables = ['SO4', 'pH', 'Tmp']

def plot_var(var_to_plot, measured_data=False):
    fig, axs = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(8, 2))
    if var_to_plot == 'Tmp':
        c=1e3
    else:
        c=1
    for ax, oid in zip(axs.flatten(), obs_to_plot ):
        tmp = obs[(obs.obsid == oid) & (obs.variable == var_to_plot)]

        ax.plot(tmp.time, tmp.sim*c, label="sim")
        if measured_data:
            ax.scatter(tmp.time, tmp.meas*c, s=15, label="meas")
        # ax.axhline(0.0007)
        ax.set_title(oid.upper())
        ax.set_ylabel(var_to_plot)

    axs[0].legend()
    fig.tight_layout()
    plt.show()

dropdown = widgets.Dropdown(
    options=variables,
    value="SO4",
    description="Variable:",
)

widgets.interact(plot_var, var_to_plot=dropdown);
